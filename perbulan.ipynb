# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('perbulan.csv')
df.head()
# Out:
#      Bulan  A. First App Open - Total  B. Read Oboarding - Total  \
# 0    April                         11                         14
# 1      Mei                         29                         70
# 2     Juni                         27                         69
# 3     Juli                         13                         37
# 4  Agustus                         16                         47
#
#    C. Sign Up - Total  D. Load Topic - Total  E. Topic Choosed - Total  \
# 0                   4                     17                        16
# 1                  24                     82                       129
# 2                  29                    160                       141
# 3                  18                     65                        68
# 4                  10                     63                        55
#
#    F. Load Learning Page - Total  G. Sub Topic Choosed - Total  \
# 0                             16                            20
# ...

# %%
df[:1]
# Out:
#    Bulan  A. First App Open - Total  B. Read Oboarding - Total  \
# 0  April                         11                         14
#
#    C. Sign Up - Total  D. Load Topic - Total  E. Topic Choosed - Total  \
# 0                   4                     17                        16
#
#    F. Load Learning Page - Total  G. Sub Topic Choosed - Total  \
# 0                             16                            20
#
#    H. Read Material - Total  I. Correct Answer Quiz - Total  \
# 0                        20                              42
#
#    J. Finish Hooray - Total  K. Exercise Choosed - Total  \
# 0                        21                           10
#
#    L. Exercise Choosed - Total  M. Correct Answer Exercise - Total  \
# 0                           10                                   6
#
#    N. Finish Hooray - Total
# 0                        21
